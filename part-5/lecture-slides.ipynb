# %% [markdown]
# # Part 5: Statistical Analysis
# A quick tour through [`cabinetry`](https://github.com/scikit-hep/cabinetry)

# %%
import copy
import glob
import json
import pathlib

import pyhf
import cabinetry

cabinetry.set_logging()

import boost_histogram as bh
import hist
import numpy as np
from pyhf.contrib.utils import download

# %% [markdown]
# <br>
#
# We will have a look at three different ways of using `cabinetry` in this notebook:
# - creating a statistical model,
# - performing statistical inference with our model,
# - exploring the statistical model of an ATLAS analysis.
#
# There is also bonus material at the end for you to look through.

# %% [markdown]
# <br>
#
# # Creating a statistical model
# Statistical models are constructed following instructions in a configuration. You can specify your model in a configuration in `YAML` or `JSON` format, or alternatively as a Python dictionary. Here we will go the dictionary route. Have a look at the `config_example.yml` file for a `YAML` example.

# %% [markdown]
# <br>
#
# ### Defining the model
#
# There are a few things we need. First up, some general settings:

# %%
config = {
   "General":{
      "Measurement": "minimal_example",
      "POI": "Signal_norm",              # parameter of interest, which we want to measure 
      "InputPath": "input/{SamplePath}", # where to find input data
      "HistogramFolder": "histograms/"

   }
}

# %% [markdown]
# Note the `input/{SamplePaths}` structure, which we will get back to shortly.
#
# Now it is time to think more about physics, let's define a phase space region that contains data we want to fit to.

# %%
config.update({
   "Regions":[
      {
         "Name": "Signal_region",
         "Filter": "lep_charge > 0",           # event selection 
         "Variable": "jet_pt",                 # which variable we bin histograms in
         "Binning": [200, 300, 400, 500, 600]
      }
   ]
})

# %% [markdown]
# `"Regions"` is a list, because we can use events from more than one phase space region.
#
# We also need to specify where our observed data is stored. Considerations about physics become important now: which types of processes do we expect to show up in this phase space region? We list them below, those samples are typically simulated with Monte Carlo methods.

# %%
config.update({
   "Samples":[
      {
         "Name": "Data",
         "Tree": "pseudodata",
         "SamplePath": "data.root",
         "Data": True                       # observed data is handled differently, need to distinguish
      },
      {
         "Name": "Signal",
         "Tree": "signal",
         "SamplePath": "prediction.root",
         "Weight": "weight"                 # weights: Monte Carlo integration, simulation correction etc.
      },
      {
         "Name": "Background",
         "Tree": "background",
         "SamplePath": "prediction.root",
         "Weight": "weight"
      }
   ]
})

# %% [markdown]
# `"Samples"` is again a list, allowing us to include arbitrarly many different types of processes we may need to consider. The `"SamplePath"` option replaces the placeholder in `input/{SamplePath}`, and specifies where each sample can be found (see the [documentation](https://cabinetry.readthedocs.io/en/latest/core.html#input-file-path-specification-for-ntuples)).
#
# We are almost done defining our statistical model. What about systematic uncertainties? For now, we won't define any.

# %%
config.update({"Systematics": []})

# %% [markdown]
# <br>
#
# There is one more thing we need though: we said our POI (parameter of interest) was `"Signal_norm"`. That is a normalization factor, describing the normalization of somthing. We still need to define what it does!

# %%
config.update({
   "NormFactors":[
      {
         "Name": "Signal_norm",
         "Samples": "Signal",    # we want this parameter to scale the signal
         "Nominal": 1,
         "Bounds": [-5, 10]
      }
   ]
})

# %% [markdown]
# <br>
#
# It is a good idea to validate that our configuration satisfies the `cabinetry` configuration schema.

# %%
cabinetry.configuration.validate(config)
# Out:
# True

# %% [markdown]
# <br>
#
# That looks good, but is not sufficient to be sure that everything is fine (some things will only show up at runtime). If we use some settings `cabinetry` does not know, or forget some it expects, we would see an error. We can also get some summary information about the configuration we defined.

# %%
cabinetry.configuration.print_overview(config)
# Out:
# INFO - cabinetry.configuration - the config contains:
# INFO - cabinetry.configuration -   3 Sample(s)
# INFO - cabinetry.configuration -   1 Regions(s)
# INFO - cabinetry.configuration -   1 NormFactor(s)
# INFO - cabinetry.configuration -   0 Systematic(s)

# %% [markdown]
# <br>
#
# ### Creating histograms
#
# We now need to create the required histograms for our statistical model. `cabinetry` implements the logic to figure out which histograms are needed, to create all instructions, and to send those off for execution. You can view our `config` as a generic specification and `cabinetry` as the reference implementation handling it, but you could just as well use your own code to interact with the specification.

# %%
cabinetry.templates.build(config, method="uproot")
# Out:
# DEBUG - cabinetry.route -   in region Signal_region
# DEBUG - cabinetry.route -     reading sample Data
# DEBUG - cabinetry.route -       variation Nominal
# DEBUG - cabinetry.contrib.histogram_creator - reading input ntuples ['input/data.root:pseudodata']
# DEBUG - cabinetry.histo - saving histogram to histograms/Signal_region_Data.npz
# DEBUG - cabinetry.route -     reading sample Signal
# DEBUG - cabinetry.route -       variation Nominal
# DEBUG - cabinetry.contrib.histogram_creator - reading input ntuples ['input/prediction.root:signal']
# WARNING - cabinetry.histo - Signal_region_Signal has empty bins: [0]
# DEBUG - cabinetry.histo - saving histogram to histograms/Signal_region_Signal.npz
# DEBUG - cabinetry.route -     reading sample Background
# DEBUG - cabinetry.route -       variation Nominal
# DEBUG - cabinetry.contrib.histogram_creator - reading input ntuples ['input/prediction.root:background']
# DEBUG - cabinetry.histo - saving histogram to histograms/Signal_region_Background.npz

# %% [markdown]
# `cabinetry` used `uproot` and `boost-histogram` to create three histograms for us: the distribution of our three samples in the one phase space region we defined. We also see a warning: there are no expected signal events in the first bin of the histogram.
#
# The histograms are saved to the folder specified under HistogramFolder in the General settings in the configuration file. In this case, this folder is `histograms/`:

# %%
glob.glob("histograms/*")
# Out:
# ['histograms/Signal_region_Data.npz',
#  'histograms/Signal_region_Signal.npz',
#  'histograms/Signal_region_Background.npz']

# %% [markdown]
# A post-processing step can be run to apply optional operations like histogram smoothing. See the bonus material.
#
# You can also provide existing histograms you built yourself for `cabinetry` to use, see the [cabinetry-tutorials](https://github.com/cabinetry/cabinetry-tutorials) repository for an example.

# %% [markdown]
# #### Visualization

# %% [markdown]
# Let's visualize the histograms we have produced.

# %%
_ = cabinetry.visualize.data_mc_from_histograms(config)
# Out:
# INFO - cabinetry.visualize - visualizing histogram
# INFO - cabinetry.histo - no modified histogram histograms/Signal_region_Background_modified.npz found, loading un-modified histogram
# INFO - cabinetry.histo - no modified histogram histograms/Signal_region_Signal_modified.npz found, loading un-modified histogram
# INFO - cabinetry.histo - no modified histogram histograms/Signal_region_Data_modified.npz found, loading un-modified histogram
# INFO - cabinetry.visualize.utils - saving figure as figures/Signal_region_prefit.pdf

# %% [markdown]
# We see our expected distributions of signal and background, as well as our observed (pseudo-) data.

# %% [markdown]
# <br>
#
# ### A more complex model: adding systematic uncertainties
#
# Let's make our model a bit more realistic and add a few systematic uncertainties:
# - a 5% luminosity uncertainty,
# - a `Modeling` uncertainty derived from comparing our nominal background prediction to that of a different simulator,
# - a `WeightBasedModeling` modeling uncertainty derived from varying the weights we apply to background events.

# %%
config.update({
   "Systematics":[
      {
         "Name": "Luminosity",
         "Up": {"Normalization": 0.05},
         "Down": {"Normalization": -0.05},
         "Type": "Normalization"
      },
      {
         "Name":"Modeling",
         "Up": {"Tree": "background_varied"},
         "Down": {"Symmetrize": True},
         "Samples": "Background",
         "Type": "NormPlusShape"
      },
      {
         "Name": "WeightBasedModeling",
         "Up": {"Weight": "weight_up"},
         "Down": {"Weight": "0.7*weight"},
         "Samples": "Background",
         "Type": "NormPlusShape"
      }
   ],
})

# %% [markdown]
# <br>
# These new systematic uncertainties require new histograms, so let's build those.

# %%
cabinetry.templates.build(config, method="uproot")
# Out:
# DEBUG - cabinetry.route -   in region Signal_region
# DEBUG - cabinetry.route -     reading sample Data
# DEBUG - cabinetry.route -       variation Nominal
# DEBUG - cabinetry.contrib.histogram_creator - reading input ntuples ['input/data.root:pseudodata']
# DEBUG - cabinetry.histo - saving histogram to histograms/Signal_region_Data.npz
# DEBUG - cabinetry.route -     reading sample Signal
# DEBUG - cabinetry.route -       variation Nominal
# DEBUG - cabinetry.contrib.histogram_creator - reading input ntuples ['input/prediction.root:signal']
# WARNING - cabinetry.histo - Signal_region_Signal has empty bins: [0]
# DEBUG - cabinetry.histo - saving histogram to histograms/Signal_region_Signal.npz
# DEBUG - cabinetry.route -     reading sample Background
# DEBUG - cabinetry.route -       variation Nominal
# DEBUG - cabinetry.contrib.histogram_creator - reading input ntuples ['input/prediction.root:background']
# DEBUG - cabinetry.histo - saving histogram to histograms/Signal_region_Background.npz
# DEBUG - cabinetry.route -       variation Modeling Up
# DEBUG - cabinetry.contrib.histogram_creator - reading input ntuples ['input/prediction.root:background_varied']
# DEBUG - cabinetry.histo - saving histogram to histograms/Signal_region_Background_Modeling_Up.npz
# DEBUG - cabinetry.route -       variation WeightBasedModeling Up
# DEBUG - cabinetry.contrib.histogram_creator - reading input ntuples ['input/prediction.root:background']
# DEBUG - cabinetry.histo - saving histogram to histograms/Signal_region_Background_WeightBasedModeling_Up.npz
# DEBUG - cabinetry.route -       variation WeightBasedModeling Down
# DEBUG - cabinetry.contrib.histogram_creator - reading input ntuples ['input/prediction.root:background']
# DEBUG - cabinetry.histo - saving histogram to histograms/Signal_region_Background_WeightBasedModeling_Down.npz

# %% [markdown]
# <br>
# We can visualize the template histograms corresponding to systematic variations of our model.

# %%
_ = cabinetry.visualize.templates(config)
# Out:
# INFO - cabinetry.visualize - visualizing systematic templates

# %% [markdown]
# The top figure is our `Modeling` uncertainty, where we compare our nominal background prediction to that of another simulator, here called the "up" variation. At the bottom are the weight-based variations: you can see the "down" variation, defined by multiplying the nominal weight by `0.7`, is a factor `0.7` smaller than nominal.

# %% [markdown]
# <br>
#
# ### Building a workspace
#
# With all relevant histograms available, we can now construct a `pyhf` workspace. This is our serialized fit model. It contains everything needed to construct a likelihood function via `pyhf`, which is then used for inference.

# %%
workspace_path = "example_workspace.json"
spec = cabinetry.workspace.build(config)
cabinetry.workspace.save(spec, workspace_path)
# Out:
# INFO - cabinetry.workspace - building workspace
# INFO - cabinetry.histo - no modified histogram histograms/Signal_region_Signal_modified.npz found, loading un-modified histogram
# DEBUG - cabinetry.workspace - adding NormFactor Signal_norm to sample Signal in region Signal_region
# DEBUG - cabinetry.workspace - adding OverallSys Luminosity to sample Signal in region Signal_region
# INFO - cabinetry.histo - no modified histogram histograms/Signal_region_Background_modified.npz found, loading un-modified histogram
# DEBUG - cabinetry.workspace - adding OverallSys Luminosity to sample Background in region Signal_region
# DEBUG - cabinetry.workspace - adding OverallSys and HistoSys Modeling to sample Background in region Signal_region
# INFO - cabinetry.histo - no modified histogram histograms/Signal_region_Background_Modeling_Up_modified.npz found, loading un-modified histogram
# INFO - cabinetry.histo - no modified histogram histograms/Signal_region_Background_modified.npz found, loading un-modified histogram
# DEBUG - cabinetry.workspace - normalization impact of systematic Modeling on sample Background in region Signal_region is 0.800
# DEBUG - cabinetry.workspace - adding OverallSys and HistoSys WeightBasedModeling to sample Background in region Signal_region
# INFO - cabinetry.histo - no modified histogram histograms/Signal_region_Background_WeightBasedModeling_Up_modified.npz found, loading un-modified histogram
# INFO - cabinetry.histo - no modified histogram histograms/Signal_region_Background_modified.npz found, loading un-modified histogram
# INFO - cabinetry.histo - no modified histogram histograms/Signal_region_Background_WeightBasedModeling_Down_modified.npz found, loading un-modified histogram
# INFO - cabinetry.histo - no modified histogram histograms/Signal_region_Data_modified.npz found, loading un-modified histogram
# INFO - pyhf.workspace - Validating spec against schema: workspace.json
# DEBUG - cabinetry.workspace - saving workspace to example_workspace.json

# %% [markdown]
# The `spec` object is a dictionary holding our workspace specification.

# %%
print(json.dumps(spec, sort_keys=True, indent=4))
# Out:
# {
#     "channels": [
#         {
#             "name": "Signal_region",
#             "samples": [
#                 {
#                     "data": [
#                         0.0,
#                         1.585369130539275,
#                         23.61642679992917,
#                         24.548922232659436
#                     ],
#                     "modifiers": [
#                         {
#                             "data": [
#                                 0.0,
#                                 0.19931165969755615,
#                                 0.7741071346184436,
#                                 0.7883050276148931
#                             ],
#                             "name": "staterror_Signal_region",
#                             "type": "staterror"
#                         },
#                         {
#                             "data": null,
#                             "name": "Signal_norm",
#                             "type": "normfactor"
#                         },
#                         {
#                             "data": {
#                                 "hi": 1.05,
#                                 "lo": 0.95
#                             },
#                             "name": "Luminosity",
#                             "type": "normsys"
#                         }
#                     ],
#                     "name": "Signal"
#                 },
#                 {
#                     "data": [
#                         112.73896936192415,
#                         128.62169538923106,
#                         88.107008384283,
#                         55.246070720721384
#                     ],
#                     "modifiers": [
#                         {
#                             "data": [
#                                 4.761366784144052,
#                                 5.106450362569687,
#                                 4.21104366965744,
#                                 3.34933334869164
#                             ],
#                             "name": "staterror_Signal_region",
#                             "type": "staterror"
#                         },
#                         {
#                             "data": {
#                                 "hi": 1.05,
#                                 "lo": 0.95
#                             },
#                             "name": "Luminosity",
#                             "type": "normsys"
#                         },
#                         {
#                             "data": {
#                                 "hi": 0.8000601197044678,
#                                 "lo": 1.1999398802955321
#                             },
#                             "name": "Modeling",
#                             "type": "normsys"
#                         },
#                         {
#                             "data": {
#                                 "hi_data": [
#                                     67.3105222742511,
#                                     106.28983773556976,
#                                     113.43998173408835,
#                                     97.67340211225037
#                                 ],
#                                 "lo_data": [
#                                     158.1674164495972,
#                                     150.95355304289237,
#                                     62.77403503447766,
#                                     12.818739329192397
#                                 ]
#                             },
#                             "name": "Modeling",
#                             "type": "histosys"
#                         },
#                         {
#                             "data": {
#                                 "hi": 1.2752596424051097,
#                                 "lo": 0.7000000000000004
#                             },
#                             "name": "WeightBasedModeling",
#                             "type": "normsys"
#                         },
#                         {
#                             "data": {
#                                 "hi_data": [
#                                     76.95350059749936,
#                                     120.85560506370255,
#                                     106.02115338037393,
#                                     80.88348481458372
#                                 ],
#                                 "lo_data": [
#                                     112.73896936192422,
#                                     128.6216953892311,
#                                     88.10700838428298,
#                                     55.24607072072132
#                                 ]
#                             },
#                             "name": "WeightBasedModeling",
#                             "type": "histosys"
#                         }
#                     ],
#                     "name": "Background"
#                 }
#             ]
#         }
#     ],
#     "measurements": [
#         {
#             "config": {
#                 "parameters": [
#                     {
#                         "bounds": [
#                             [
#                                 -5,
#                                 10
#                             ]
#                         ],
#                         "inits": [
#                             1
#                         ],
#                         "name": "Signal_norm"
#                     }
#                 ],
#                 "poi": "Signal_norm"
#             },
#             "name": "minimal_example"
#         }
#     ],
#     "observations": [
#         {
#             "data": [
#                 112.0,
#                 112.0,
#                 124.0,
#                 66.0
#             ],
#             "name": "Signal_region"
#         }
#     ],
#     "version": "1.0.0"
# }

# %% [markdown]
# Saving is optional, we could directly continue with the `spec` object. `pyhf` has validated our workspace, and we are now ready for statistical inference.

# %% [markdown]
# <br>
#
# ### Model structure
#
# It can be helpful to visualize the modifier structure of the statistical model we have built to catch potential issues. The `visualize.modifier_grid` function creates a figure showcasing the information about which modifiers (indicated by color) act on which region and sample when a given parameter (on the horizontal axis) is varied. To split this visualization from one table per region to one table per sample, use `split_by_sample=True`.
#
# We need the fit model (containing the probability density function) for the visualization, which we create from the workspace specification. We directly use the `pyhf` API for this here, in the next section you will see the `cabinetry` API used for the same task.

# %%
cabinetry.visualize.modifier_grid(pyhf.Workspace(spec).model())
# Out:
# INFO - pyhf.workspace - Validating spec against schema: workspace.json
# INFO - pyhf.pdf - Validating spec against schema: model.json
# INFO - pyhf.pdf - adding modifier Modeling (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier WeightBasedModeling (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier Signal_norm (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier Luminosity (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier staterror_Signal_region (4 new nuisance parameters)
# INFO - cabinetry.visualize.utils - saving figure as figures/modifier_grid.pdf

# %% [markdown]
# <br>
#
# # Performing statistical inference with our model
#
# To perform inference, we need two things: a probability density function (pdf), or `model`, and data to fit it to. Both are derived from the workspace specification.

# %%
model, data = cabinetry.model_utils.model_and_data(spec)
# Out:
# INFO - pyhf.workspace - Validating spec against schema: workspace.json
# INFO - pyhf.pdf - Validating spec against schema: model.json
# INFO - pyhf.pdf - adding modifier Modeling (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier WeightBasedModeling (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier Signal_norm (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier Luminosity (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier staterror_Signal_region (4 new nuisance parameters)

# %% [markdown]
# You can see our `Signal_norm` normalization showing up, in addition to parameters for the systematic uncertainties we defined.
#
# There is also `staterror_Signal_region`: these are parameters automatically created by `cabinetry` to encode systematic uncertainty due to the finite sample size of our predicted distributions for signal and background.
#
# `data` is a list, starting with the observed counts per bin.

# %%
data
# Out:
# [112.0, 112.0, 124.0, 66.0, 0.0, 0.0, 0.0, 1.0, 1.0, 1.0, 1.0]

# %% [markdown]
# What comes after is so-called auxiliary data. Check out [this `pyhf` tutorial](https://pyhf.github.io/pyhf-tutorial/HelloWorld.html#auxiliary-data) to learn more about this important concept. You can view it as data observed in previous measurements, which inform our current model. In this case the auxiliary data is associated to the `staterror_Signal_region` parameter.

# %% [markdown]
# <br>
#
# ### Maximum likelihood estimate (MLE)
#
# Let's fit our model to data to obtain the maximum likelihood estimate (MLE).

# %%
fit_results = cabinetry.fit.fit(model, data)
# Out:
# INFO - cabinetry.fit - performing maximum likelihood fit
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 17.19                      │              Nfcn = 310              │
# │ EDM = 2.82e-05 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 17.194232 at best-fit point
# INFO - cabinetry.fit - fit results (with symmetric uncertainties):
# INFO - cabinetry.fit - Modeling                   = -0.3258 +/- 0.5551
# INFO - cabinetry.fit - WeightBasedModeling        = -0.5868 +/- 0.6266
# INFO - cabinetry.fit - Signal_norm                =  1.6927 +/- 0.9455
# INFO - cabinetry.fit - Luminosity                 = -0.0899 +/- 0.9915
# INFO - cabinetry.fit - staterror_Signal_region[0] =  1.0009 +/- 0.0411
# INFO - cabinetry.fit - staterror_Signal_region[1] =  0.9891 +/- 0.0379
# INFO - cabinetry.fit - staterror_Signal_region[2] =  1.0197 +/- 0.0365
# INFO - cabinetry.fit - staterror_Signal_region[3] =  0.9829 +/- 0.0425

# %% [markdown]
# <br>
# The fit converged, and we see the best-fit parameter results reported. The results are stored in a named tuple. This allows for easy access of the results.

# %%
for label, result, unc in zip(fit_results.labels, fit_results.bestfit, fit_results.uncertainty):
    print(f"{label}: {result:.3f} +/- {unc:.3f}")
# Out:
# Modeling: -0.326 +/- 0.555
# WeightBasedModeling: -0.587 +/- 0.627
# Signal_norm: 1.693 +/- 0.946
# Luminosity: -0.090 +/- 0.991
# staterror_Signal_region[0]: 1.001 +/- 0.041
# staterror_Signal_region[1]: 0.989 +/- 0.038
# staterror_Signal_region[2]: 1.020 +/- 0.037
# staterror_Signal_region[3]: 0.983 +/- 0.043

# %% [markdown]
# <br>
#
# It is helpful to visualize the fit results. Let's start with the *pull plot* showing us best-fit parameter results.

# %%
cabinetry.visualize.pulls(fit_results, exclude="Signal_norm")
# Out:
# INFO - cabinetry.visualize.utils - saving figure as figures/pulls.pdf

# %% [markdown]
# <br>
#
# The parameter correlation matrix has a handy `pruning_threshold` setting to filter out parameters that are not highly correlated with others.

# %%
cabinetry.visualize.correlation_matrix(fit_results, pruning_threshold=0.1)
# Out:
# INFO - cabinetry.visualize.utils - saving figure as figures/correlation_matrix.pdf

# %% [markdown]
# <br>
# How does the model look like after fit to data? Let's first look again at the model before the fit to data. We use information from the workspace for plotting, and from the config for cosmetics (axis label / binning). The results include the effect of systematic uncertainties.

# %%
model_pred = cabinetry.model_utils.prediction(model)
figures = cabinetry.visualize.data_mc(model_pred, data, config=config)
# Out:
# DEBUG - cabinetry.model_utils - total stdev is [[69.04078931427513, 58.343327786463256, 38.21959892946073, 45.2969637489918]]
# DEBUG - cabinetry.model_utils - total stdev per channel is [136.79197821730315]
# INFO - cabinetry.visualize.utils - saving figure as figures/Signal_region_prefit.pdf

# %% [markdown]
# It is possible to edit the figures created by `cabinetry` using the `matplotlib` API. The example below modifies an axis label to use $\LaTeX$. `cabinetry` version 0.5.2 also added the possibility to more conveniently change the colors of histograms in the stack as shown below.

# %%
figures = cabinetry.visualize.data_mc(model_pred, data, config=config,
                                      colors={"Signal": "tomato", "Background": "navajowhite"}, close_figure=True)
ratio_panel = figures[0]["figure"].get_axes()[1]
ratio_panel.set_xlabel("jet $p_T$")
figures[0]["figure"]  # show figure
# Out:
# INFO - cabinetry.visualize.utils - saving figure as figures/Signal_region_prefit.pdf

# %% [markdown]
# Yield tables can also be created from a model prediction, and compared to data. Optional keyword arguments control whether yields per bin are shown (`per_bin=True`, default) and whether bins summed per region are shown (`per_channel=True`, disabled by default). The yield table is also saved to disk by default, in a format customizable via the `table_format` argument.

# %%
_ = cabinetry.tabulate.yields(model_pred, data)
# Out:
# INFO - cabinetry.tabulate - yields per bin for pre-fit model prediction:
# ╒════════════╤═════════════════╤════════════════╤════════════════╤═══════════════╕
# │ sample     │ Signal_region   │                │                │               │
# │            │ bin 1           │ bin 2          │ bin 3          │ bin 4         │
# ╞════════════╪═════════════════╪════════════════╪════════════════╪═══════════════╡
# │ Background │ 112.74 ± 69.04  │ 128.62 ± 58.33 │ 88.11 ± 37.97  │ 55.25 ± 45.14 │
# ├────────────┼─────────────────┼────────────────┼────────────────┼───────────────┤
# │ Signal     │ 0.00 ± 0.00     │ 1.59 ± 0.10    │ 23.62 ± 1.49   │ 24.55 ± 1.62  │
# ├────────────┼─────────────────┼────────────────┼────────────────┼───────────────┤
# │ total      │ 112.74 ± 69.04  │ 130.21 ± 58.34 │ 111.72 ± 38.22 │ 79.79 ± 45.30 │
# ├────────────┼─────────────────┼────────────────┼────────────────┼───────────────┤
# │ data       │ 112.00          │ 112.00         │ 124.00         │ 66.00         │
# ╘════════════╧═════════════════╧════════════════╧════════════════╧═══════════════╛
# INFO - cabinetry.tabulate - saving table as tables/yields_per_bin_pre-fit.txt

# %% [markdown]
# This table was also saved to disk.

# %%
# !cat tables/yields_per_bin_pre-fit.txt
# Out:
# sample      Signal_region    Signal_region    Signal_region    Signal_region
#             bin 1            bin 2            bin 3            bin 4
# ----------  ---------------  ---------------  ---------------  ---------------
# Background  112.74 ± 69.04   128.62 ± 58.33   88.11 ± 37.97    55.25 ± 45.14
# Signal      0.00 ± 0.00      1.59 ± 0.10      23.62 ± 1.49     24.55 ± 1.62
# total       112.74 ± 69.04   130.21 ± 58.34   111.72 ± 38.22   79.79 ± 45.30
# data        112.00           112.00           124.00           66.00

# %% [markdown]
# <br>
#
# We create the post-fit version of this plot by passing in `fit_results`.

# %%
model_pred_postfit = cabinetry.model_utils.prediction(model, fit_results=fit_results)
_ = cabinetry.visualize.data_mc(model_pred_postfit, data, config=config)
# Out:
# DEBUG - cabinetry.model_utils - total stdev is [[11.875938194632312, 7.284378565685542, 7.472065202648362, 7.667716425278941]]
# DEBUG - cabinetry.model_utils - total stdev per channel is [20.60249984820742]
# INFO - cabinetry.visualize.utils - saving figure as figures/Signal_region_postfit.pdf

# %% [markdown]
# The contribution of signal in green has increased, consistent with the normalization `Signal_norm` having been fit to a value greater than `1`.

# %% [markdown]
# <br>
#
# ### Expected sensitivity with the Asimov dataset
#
# We can evaluate the expected performance of our model with the so-called Asimov dataset (see [arXiv:1007.1727](https://arxiv.org/abs/1007.1727)).

# %%
asimov_data = cabinetry.model_utils.asimov_data(model)
_ = cabinetry.fit.fit(model, asimov_data)
# Out:
# INFO - cabinetry.fit - performing maximum likelihood fit
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 13.3                       │              Nfcn = 176              │
# │ EDM = 2.61e-16 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 13.296992 at best-fit point
# INFO - cabinetry.fit - fit results (with symmetric uncertainties):
# INFO - cabinetry.fit - Modeling                   =  0.0000 +/- 0.2509
# INFO - cabinetry.fit - WeightBasedModeling        =  0.0000 +/- 0.5798
# INFO - cabinetry.fit - Signal_norm                =  1.0000 +/- 0.9989
# INFO - cabinetry.fit - Luminosity                 =  0.0000 +/- 0.9875
# INFO - cabinetry.fit - staterror_Signal_region[0] =  1.0000 +/- 0.0416
# INFO - cabinetry.fit - staterror_Signal_region[1] =  1.0000 +/- 0.0384
# INFO - cabinetry.fit - staterror_Signal_region[2] =  1.0000 +/- 0.0367
# INFO - cabinetry.fit - staterror_Signal_region[3] =  1.0000 +/- 0.0421
# W VariableMetricBuilder No improvement in line search

# %% [markdown]
# By definition, none of the parameters are pulled away from their initial values in this fit.

# %% [markdown]
# <br>
#
# ### Beyond MLEs: discovery significance and parameter limits
#
# Now that we ran a basic fit, let's do something slightly more involved: calculate discovery significance.

# %%
significance_results = cabinetry.fit.significance(model, data)
# Out:
# INFO - cabinetry.fit - calculating discovery significance for Signal_norm
# INFO - cabinetry.fit - observed p-value: 3.584%
# INFO - cabinetry.fit - observed significance: 1.801
# INFO - cabinetry.fit - expected p-value: 14.775%
# INFO - cabinetry.fit - expected significance: 1.046

# %% [markdown]
# The results are again packaged up in a named tuple. The observed significance is higher than the expected significance, consistent with fitting a `Signal_norm` value above one.
#
# We can also calculate expected and observed 95% confidence level upper parameter limits with the [CLs method](https://doi.org/10.1088%2F0954-3899%2F28%2F10%2F313). The implementation uses Brent bracketing to find `CLs=0.05` crossings. Let's use slightly different data for this: it is simple to switch out!

# %%
data_limit = [112, 129, 92, 63] + model.config.auxdata  # need auxiliary data as well
limit_results = cabinetry.fit.limit(model, data_limit)
cabinetry.visualize.limit(limit_results)
# Out:
# INFO - cabinetry.fit - calculating 95% confidence level upper limit for Signal_norm
# DEBUG - cabinetry.fit - setting lower parameter bound for POI to 0
# INFO - cabinetry.fit - determining observed upper limit
# DEBUG - cabinetry.fit - Signal_norm = 0.1000, observed CLs = 0.9222
# DEBUG - cabinetry.fit - Signal_norm = 10.0000, observed CLs = 0.0000
# DEBUG - cabinetry.fit - Signal_norm = 9.4633, observed CLs = 0.0000
# DEBUG - cabinetry.fit - Signal_norm = 4.7816, observed CLs = 0.0000
# DEBUG - cabinetry.fit - Signal_norm = 2.4408, observed CLs = 0.0181
# DEBUG - cabinetry.fit - Signal_norm = 1.2704, observed CLs = 0.2544
# DEBUG - cabinetry.fit - Signal_norm = 2.2830, observed CLs = 0.0288
# DEBUG - cabinetry.fit - Signal_norm = 1.9986, observed CLs = 0.0606
# DEBUG - cabinetry.fit - Signal_norm = 2.0935, observed CLs = 0.0479
# DEBUG - cabinetry.fit - Signal_norm = 2.0777, observed CLs = 0.0498
# DEBUG - cabinetry.fit - Signal_norm = 2.0727, observed CLs = 0.0505
# INFO - cabinetry.fit - successfully converged after 11 steps
# INFO - cabinetry.fit - observed upper limit: 2.0777
# INFO - cabinetry.fit - determining expected -2 sigma upper limit
# DEBUG - cabinetry.fit - Signal_norm = 0.1000, expected -2 sigma CLs = 0.7740 (cached)
# DEBUG - cabinetry.fit - Signal_norm = 1.2704, expected -2 sigma CLs = 0.0255 (cached)
# DEBUG - cabinetry.fit - Signal_norm = 1.2321, expected -2 sigma CLs = 0.0291
# DEBUG - cabinetry.fit - Signal_norm = 1.0153, expected -2 sigma CLs = 0.0592
# DEBUG - cabinetry.fit - Signal_norm = 1.0814, expected -2 sigma CLs = 0.0479
# DEBUG - cabinetry.fit - Signal_norm = 1.0693, expected -2 sigma CLs = 0.0498
# DEBUG - cabinetry.fit - Signal_norm = 1.0643, expected -2 sigma CLs = 0.0507
# INFO - cabinetry.fit - successfully converged after 7 steps
# INFO - cabinetry.fit - expected -2 sigma upper limit: 1.0693
# INFO - cabinetry.fit - determining expected -1 sigma upper limit
# DEBUG - cabinetry.fit - Signal_norm = 1.2704, expected -1 sigma CLs = 0.0773 (cached)
# DEBUG - cabinetry.fit - Signal_norm = 1.9986, expected -1 sigma CLs = 0.0083 (cached)
# DEBUG - cabinetry.fit - Signal_norm = 1.5588, expected -1 sigma CLs = 0.0350
# DEBUG - cabinetry.fit - Signal_norm = 1.4567, expected -1 sigma CLs = 0.0470
# DEBUG - cabinetry.fit - Signal_norm = 1.4333, expected -1 sigma CLs = 0.0501
# DEBUG - cabinetry.fit - Signal_norm = 1.4383, expected -1 sigma CLs = 0.0494
# INFO - cabinetry.fit - successfully converged after 6 steps
# INFO - cabinetry.fit - expected -1 sigma upper limit: 1.4333
# INFO - cabinetry.fit - determining expected upper limit
# DEBUG - cabinetry.fit - Signal_norm = 1.5588, expected CLs = 0.1238 (cached)
# DEBUG - cabinetry.fit - Signal_norm = 1.9986, expected CLs = 0.0447 (cached)
# DEBUG - cabinetry.fit - Signal_norm = 1.9691, expected CLs = 0.0482
# DEBUG - cabinetry.fit - Signal_norm = 1.9548, expected CLs = 0.0500
# DEBUG - cabinetry.fit - Signal_norm = 1.9598, expected CLs = 0.0494
# INFO - cabinetry.fit - successfully converged after 5 steps
# INFO - cabinetry.fit - expected upper limit: 1.9548
# INFO - cabinetry.fit - determining expected +1 sigma upper limit
# DEBUG - cabinetry.fit - Signal_norm = 2.4408, expected +1 sigma CLs = 0.0788 (cached)
# DEBUG - cabinetry.fit - Signal_norm = 4.7816, expected +1 sigma CLs = 0.0000 (cached)
# DEBUG - cabinetry.fit - Signal_norm = 3.2972, expected +1 sigma CLs = 0.0069
# DEBUG - cabinetry.fit - Signal_norm = 2.7842, expected +1 sigma CLs = 0.0339
# DEBUG - cabinetry.fit - Signal_norm = 2.6610, expected +1 sigma CLs = 0.0467
# DEBUG - cabinetry.fit - Signal_norm = 2.6329, expected +1 sigma CLs = 0.0501
# DEBUG - cabinetry.fit - Signal_norm = 2.6379, expected +1 sigma CLs = 0.0495
# INFO - cabinetry.fit - successfully converged after 7 steps
# INFO - cabinetry.fit - expected +1 sigma upper limit: 2.6329
# INFO - cabinetry.fit - determining expected +2 sigma upper limit
# DEBUG - cabinetry.fit - Signal_norm = 3.2972, expected +2 sigma CLs = 0.0654 (cached)
# DEBUG - cabinetry.fit - Signal_norm = 4.7816, expected +2 sigma CLs = 0.0003 (cached)
# DEBUG - cabinetry.fit - Signal_norm = 3.6484, expected +2 sigma CLs = 0.0256
# DEBUG - cabinetry.fit - Signal_norm = 3.4330, expected +2 sigma CLs = 0.0465
# DEBUG - cabinetry.fit - Signal_norm = 3.4079, expected +2 sigma CLs = 0.0496
# DEBUG - cabinetry.fit - Signal_norm = 3.4029, expected +2 sigma CLs = 0.0503
# INFO - cabinetry.fit - successfully converged after 6 steps
# INFO - cabinetry.fit - expected +2 sigma upper limit: 3.4029
# INFO - cabinetry.fit - total of 42 steps to calculate all limits
# INFO - cabinetry.fit - summary of 95% confidence level upper limits:
# INFO - cabinetry.fit - observed         : 2.0777
# INFO - cabinetry.fit - expected -2 sigma: 1.0693
# INFO - cabinetry.fit - expected -1 sigma: 1.4333
# INFO - cabinetry.fit - expected         : 1.9548
# INFO - cabinetry.fit - expected +1 sigma: 2.6329
# INFO - cabinetry.fit - expected +2 sigma: 3.4029
# INFO - cabinetry.visualize.utils - saving figure as figures/limit.pdf

# %% [markdown]
# The observed limit follows the expectation quite closely with this new data we have used, which is very similar to the background-only prediction.

# %% [markdown]
# <br>
#
# # Exploring the statistical model of an ATLAS analysis
#
# Let's explore the statistical model used in an ATLAS search for electroweakinos: [Eur.Phys.J.C 80 (2020) 8, 691](https://inspirehep.net/literature/1755298). The corresponding likelihoods are available on HEPData: [doi:10.17182/hepdata.90607.v2](https://doi.org/10.17182/hepdata.90607.v2).
#
# We can download it, pick one of the available signals with `pyhf`, and are ready to go.

# %%
download("https://www.hepdata.net/record/resource/1267798?view=true", "electroweakinos")
ATLAS_ws = pyhf.Workspace(json.load(open("electroweakinos/1Lbb-likelihoods-hepdata/BkgOnly.json")))
patchset = pyhf.PatchSet(json.load(open("electroweakinos/1Lbb-likelihoods-hepdata/patchset.json")))
ATLAS_ws = patchset.apply(ATLAS_ws, "C1N2_Wh_hbb_700_400")
cabinetry.workspace.save(ATLAS_ws, "electroweakinos.json")
# Out:
# INFO - pyhf.workspace - Validating spec against schema: workspace.json
# INFO - pyhf.patchset - Validating spec against schema: patchset.json
# INFO - pyhf.workspace - Validating spec against schema: workspace.json
# DEBUG - cabinetry.workspace - saving workspace to electroweakinos.json

# %% [markdown]
# <br>`pyhf` has a helpful command line interface utility to summarize the workspace content.

# %%
# !pyhf inspect electroweakinos.json | head -n 6
# Out:
#                                     Summary
#                               ------------------
#                                  channels  8
#                                   samples  10
#                                parameters  120
#                                 modifiers  120

# %% [markdown]
# <br>
#
# Let's extract model and data with `cabinetry`.

# %%
ATLAS_model, ATLAS_data = cabinetry.model_utils.model_and_data(ATLAS_ws)
# Out:
# INFO - pyhf.workspace - Validating spec against schema: workspace.json
# INFO - pyhf.pdf - Validating spec against schema: model.json
# INFO - pyhf.pdf - adding modifier EG_Eff (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier EG_Iso (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier EG_RESOLUTION_ALL (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier EG_Reco (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier EG_SCALE_AF2 (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier EG_SCALE_ALL (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JER_DataVsMC (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JER_EffectiveNP_1 (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JER_EffectiveNP_10 (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JER_EffectiveNP_11 (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JER_EffectiveNP_12restTerm (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JER_EffectiveNP_2 (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JER_EffectiveNP_3 (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JER_EffectiveNP_4 (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JER_EffectiveNP_5 (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JER_EffectiveNP_6 (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JER_EffectiveNP_7 (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JER_EffectiveNP_8 (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JER_EffectiveNP_9 (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_BJES_Response (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_Comb_Baseline_Kin (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_Comb_Modelling_Kin (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_Comb_TotalStat_Kin (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_Comb_Tracking_Kin (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_EffectiveNP_Detector1 (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_EffectiveNP_Detector2 (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_EffectiveNP_Mixed1 (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_EffectiveNP_Mixed2 (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_EffectiveNP_Mixed3 (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_EffectiveNP_Modelling1 (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_EffectiveNP_Modelling2 (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_EffectiveNP_Modelling3 (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_EffectiveNP_Modelling4 (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_EffectiveNP_Statistical1 (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_EffectiveNP_Statistical2 (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_EffectiveNP_Statistical3 (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_EffectiveNP_Statistical4 (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_EffectiveNP_Statistical5 (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_EffectiveNP_Statistical6 (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_EtaIntercalibration_Modelling (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_EtaIntercalibration_NonClosure_highE (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_EtaIntercalibration_NonClosure_negEta (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_EtaIntercalibration_NonClosure_posEta (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_EtaIntercalibration_TotalStat (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_Flavor_Composition (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_Flavor_Response (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_Pileup_OffsetMu (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_Pileup_OffsetNPV (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_Pileup_PtTerm (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_Pileup_RhoTopology (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_SingleParticle_HighPt (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JVT (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier MET_SoftTrk (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier MET_SoftTrk_ResoPara (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier MET_SoftTrk_ResoPerp (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier MUON_Eff_BadMuon_stat (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier MUON_Eff_BadMuon_sys (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier MUON_Eff_Iso_stat (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier MUON_Eff_Iso_sys (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier MUON_Eff_stat (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier MUON_Eff_stat_lowpt (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier MUON_Eff_sys (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier MUON_Eff_sys_lowpt (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier MUON_ID (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier MUON_MS (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier MUON_SAGITTA_RESBIAS (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier MUON_SAGITTA_RHO (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier MUON_SCALE (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier MUON_TTVA_stat (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier MUON_TTVA_sys (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier SigTheoRad (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier SigTheoSigQc (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier SigTheoSigSc (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier btag_BT (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier btag_CT (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier btag_Extra (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier btag_ExtraFromCharm (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier btag_LightT (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier pileup (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier JES_PunchThrough_MC16 (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier diboson (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier singletopFSR (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier singletopFragHad (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier singletopHardScattering (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier singletopISR (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier singletopInterference (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier TtbarFSR (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier TtbarFragmentation (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier TtbarHardscattering (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier TtbarISR (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier ttvRenormFac (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier wjetsCKKW (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier wjetsPDF (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier wjetsQSF (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier wjetsRenormFac (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier multiboson (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier zjetsCKKW (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier zjetsPDF (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier zjetsQSF (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier zjetsRenormFac (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier lumi (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier mu_SIG (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier mu_ST (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier mu_Top (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier mu_W (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier SigXSec (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier trigger (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier diboson_XS (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier ttH_XS (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier ttv_XS (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier multiboson_XS (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier zjets_XS (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier staterror_SRHMEM_mct2 (3 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier staterror_SRLMEM_mct2 (3 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier staterror_SRMMEM_mct2 (3 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier staterror_STCREM_cuts (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier staterror_TRHMEM_cuts (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier staterror_TRLMEM_cuts (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier staterror_TRMMEM_cuts (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier staterror_WREM_cuts (1 new nuisance parameters)

# %% [markdown]
# <br>
# We are ready to take a closer look at the content. Which phase space regions are included?

# %%
ATLAS_model_pred = cabinetry.model_utils.prediction(ATLAS_model)
_ = cabinetry.visualize.data_mc(ATLAS_model_pred, ATLAS_data)
# Out:
# DEBUG - cabinetry.model_utils - total stdev is [[2.529533663461986, 1.7401491012109056, 0.637908099071494], [3.111601746543452, 3.1080820725566376, 2.1549087509801756], [2.541446028405515, 1.645269629872483, 0.6753290017000224], [45.78418686812698], [49.377826228780414], [78.26453949517607], [33.307108976295716], [12.994563932736522]]
# DEBUG - cabinetry.model_utils - total stdev per channel is [3.6621236064082687, 5.127804795941434, 2.690116414565473, 45.78418686812698, 49.377826228780414, 78.26453949517607, 33.307108976295716, 12.994563932736522]
# INFO - cabinetry.visualize.utils - saving figure as figures/SRHMEM_mct2_prefit.pdf
# INFO - cabinetry.visualize.utils - saving figure as figures/SRLMEM_mct2_prefit.pdf
# INFO - cabinetry.visualize.utils - saving figure as figures/SRMMEM_mct2_prefit.pdf
# INFO - cabinetry.visualize.utils - saving figure as figures/STCREM_cuts_prefit.pdf
# INFO - cabinetry.visualize.utils - saving figure as figures/TRHMEM_cuts_prefit.pdf
# INFO - cabinetry.visualize.utils - saving figure as figures/TRLMEM_cuts_prefit.pdf
# INFO - cabinetry.visualize.utils - saving figure as figures/TRMMEM_cuts_prefit.pdf
# INFO - cabinetry.visualize.utils - saving figure as figures/WREM_cuts_prefit.pdf

# %% [markdown]
# <br>
# Let's fit this model to data.

# %%
ATLAS_fit_results = cabinetry.fit.fit(ATLAS_model, ATLAS_data)
# Out:
# INFO - cabinetry.fit - performing maximum likelihood fit
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 218.4                      │             Nfcn = 22347             │
# │ EDM = 6e-05 (Goal: 0.0002)       │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 218.408212 at best-fit point
# INFO - cabinetry.fit - fit results (with symmetric uncertainties):
# INFO - cabinetry.fit - EG_Eff                                    = -0.1006 +/- 0.9921
# INFO - cabinetry.fit - EG_Iso                                    = -0.0656 +/- 0.9914
# INFO - cabinetry.fit - EG_RESOLUTION_ALL                         = -0.0267 +/- 1.0304
# INFO - cabinetry.fit - EG_Reco                                   = -0.0224 +/- 0.9932
# INFO - cabinetry.fit - EG_SCALE_AF2                              =  0.0000 +/- 0.9933
# INFO - cabinetry.fit - EG_SCALE_ALL                              = -0.1236 +/- 1.0850
# INFO - cabinetry.fit - JER_DataVsMC                              = -0.0880 +/- 1.1170
# INFO - cabinetry.fit - JER_EffectiveNP_1                         = -0.2565 +/- 1.0047
# INFO - cabinetry.fit - JER_EffectiveNP_10                        = -0.0358 +/- 1.0914
# INFO - cabinetry.fit - JER_EffectiveNP_11                        = -0.0317 +/- 1.0890
# INFO - cabinetry.fit - JER_EffectiveNP_12restTerm                =  0.1303 +/- 0.9742
# INFO - cabinetry.fit - JER_EffectiveNP_2                         =  0.2250 +/- 0.8433
# INFO - cabinetry.fit - JER_EffectiveNP_3                         =  0.0887 +/- 0.8805
# INFO - cabinetry.fit - JER_EffectiveNP_4                         =  0.0110 +/- 1.1295
# INFO - cabinetry.fit - JER_EffectiveNP_5                         = -0.4376 +/- 1.0466
# INFO - cabinetry.fit - JER_EffectiveNP_6                         =  0.1461 +/- 1.1344
# INFO - cabinetry.fit - JER_EffectiveNP_7                         = -0.0288 +/- 1.1331
# INFO - cabinetry.fit - JER_EffectiveNP_8                         =  0.2327 +/- 1.0435
# INFO - cabinetry.fit - JER_EffectiveNP_9                         = -0.0099 +/- 1.0534
# INFO - cabinetry.fit - JES_BJES_Response                         = -0.0000 +/- 0.9933
# INFO - cabinetry.fit - JES_Comb_Baseline_Kin                     = -0.0000 +/- 0.9933
# INFO - cabinetry.fit - JES_Comb_Modelling_Kin                    =  0.0000 +/- 0.9933
# INFO - cabinetry.fit - JES_Comb_TotalStat_Kin                    =  0.0000 +/- 0.9933
# INFO - cabinetry.fit - JES_Comb_Tracking_Kin                     = -0.0000 +/- 0.9933
# INFO - cabinetry.fit - JES_EffectiveNP_Detector1                 = -0.0135 +/- 0.9316
# INFO - cabinetry.fit - JES_EffectiveNP_Detector2                 = -0.0035 +/- 0.9793
# INFO - cabinetry.fit - JES_EffectiveNP_Mixed1                    = -0.0579 +/- 1.0490
# INFO - cabinetry.fit - JES_EffectiveNP_Mixed2                    = -0.0337 +/- 1.0222
# INFO - cabinetry.fit - JES_EffectiveNP_Mixed3                    =  0.0016 +/- 0.9686
# INFO - cabinetry.fit - JES_EffectiveNP_Modelling1                =  0.3195 +/- 1.2390
# INFO - cabinetry.fit - JES_EffectiveNP_Modelling2                = -0.0655 +/- 0.9354
# INFO - cabinetry.fit - JES_EffectiveNP_Modelling3                =  0.0055 +/- 0.9610
# INFO - cabinetry.fit - JES_EffectiveNP_Modelling4                = -0.0240 +/- 0.9113
# INFO - cabinetry.fit - JES_EffectiveNP_Statistical1              = -0.0433 +/- 0.9553
# INFO - cabinetry.fit - JES_EffectiveNP_Statistical2              = -0.0594 +/- 0.8949
# INFO - cabinetry.fit - JES_EffectiveNP_Statistical3              =  0.0213 +/- 0.9607
# INFO - cabinetry.fit - JES_EffectiveNP_Statistical4              =  0.0534 +/- 0.9363
# INFO - cabinetry.fit - JES_EffectiveNP_Statistical5              =  0.0177 +/- 0.8938
# INFO - cabinetry.fit - JES_EffectiveNP_Statistical6              =  0.0237 +/- 0.9846
# INFO - cabinetry.fit - JES_EtaIntercalibration_Modelling         = -0.0925 +/- 1.0805
# INFO - cabinetry.fit - JES_EtaIntercalibration_NonClosure_highE  = -0.0071 +/- 0.9906
# INFO - cabinetry.fit - JES_EtaIntercalibration_NonClosure_negEta =  0.0024 +/- 1.0067
# INFO - cabinetry.fit - JES_EtaIntercalibration_NonClosure_posEta = -0.0016 +/- 0.9907
# INFO - cabinetry.fit - JES_EtaIntercalibration_TotalStat         = -0.0130 +/- 0.9162
# INFO - cabinetry.fit - JES_Flavor_Composition                    =  0.6347 +/- 0.8771
# INFO - cabinetry.fit - JES_Flavor_Response                       = -0.5579 +/- 0.9690
# INFO - cabinetry.fit - JES_Pileup_OffsetMu                       =  0.2183 +/- 1.1846
# INFO - cabinetry.fit - JES_Pileup_OffsetNPV                      =  0.3197 +/- 1.1929
# INFO - cabinetry.fit - JES_Pileup_PtTerm                         =  0.0137 +/- 0.9570
# INFO - cabinetry.fit - JES_Pileup_RhoTopology                    =  0.2174 +/- 1.4013
# INFO - cabinetry.fit - JES_SingleParticle_HighPt                 =  0.0000 +/- 0.9933
# INFO - cabinetry.fit - JVT                                       = -0.0050 +/- 0.9568
# INFO - cabinetry.fit - MET_SoftTrk                               =  0.1364 +/- 0.9534
# INFO - cabinetry.fit - MET_SoftTrk_ResoPara                      =  0.1495 +/- 0.9655
# INFO - cabinetry.fit - MET_SoftTrk_ResoPerp                      = -0.1013 +/- 0.9455
# INFO - cabinetry.fit - MUON_Eff_BadMuon_stat                     =  0.0000 +/- 0.9933
# INFO - cabinetry.fit - MUON_Eff_BadMuon_sys                      =  0.0000 +/- 0.9933
# INFO - cabinetry.fit - MUON_Eff_Iso_stat                         = -0.0046 +/- 0.9933
# INFO - cabinetry.fit - MUON_Eff_Iso_sys                          = -0.0062 +/- 0.9934
# INFO - cabinetry.fit - MUON_Eff_stat                             =  0.0009 +/- 0.9935
# INFO - cabinetry.fit - MUON_Eff_stat_lowpt                       = -0.0023 +/- 0.9933
# INFO - cabinetry.fit - MUON_Eff_sys                              = -0.0089 +/- 0.9931
# INFO - cabinetry.fit - MUON_Eff_sys_lowpt                        = -0.0065 +/- 0.9933
# INFO - cabinetry.fit - MUON_ID                                   = -0.0690 +/- 1.0150
# INFO - cabinetry.fit - MUON_MS                                   =  0.1071 +/- 1.0057
# INFO - cabinetry.fit - MUON_SAGITTA_RESBIAS                      =  0.0496 +/- 0.8389
# INFO - cabinetry.fit - MUON_SAGITTA_RHO                          = -0.0000 +/- 0.9933
# INFO - cabinetry.fit - MUON_SCALE                                =  0.0220 +/- 0.8843
# INFO - cabinetry.fit - MUON_TTVA_stat                            = -0.0002 +/- 0.9934
# INFO - cabinetry.fit - MUON_TTVA_sys                             = -0.0007 +/- 0.9934
# INFO - cabinetry.fit - SigTheoRad                                =  0.0034 +/- 0.9947
# INFO - cabinetry.fit - SigTheoSigQc                              =  0.0005 +/- 0.9909
# INFO - cabinetry.fit - SigTheoSigSc                              =  0.0014 +/- 0.9845
# INFO - cabinetry.fit - btag_BT                                   = -0.0145 +/- 0.9924
# INFO - cabinetry.fit - btag_CT                                   =  0.0868 +/- 0.9831
# INFO - cabinetry.fit - btag_Extra                                = -0.0538 +/- 0.9922
# INFO - cabinetry.fit - btag_ExtraFromCharm                       =  0.0405 +/- 0.9924
# INFO - cabinetry.fit - btag_LightT                               = -0.0756 +/- 0.9884
# INFO - cabinetry.fit - pileup                                    =  0.0107 +/- 1.0025
# INFO - cabinetry.fit - JES_PunchThrough_MC16                     = -0.0081 +/- 0.9937
# INFO - cabinetry.fit - diboson                                   =  0.0063 +/- 0.9904
# INFO - cabinetry.fit - singletopFSR                              = -0.0171 +/- 0.7232
# INFO - cabinetry.fit - singletopFragHad                          = -0.3912 +/- 0.8534
# INFO - cabinetry.fit - singletopHardScattering                   =  0.5430 +/- 0.6059
# INFO - cabinetry.fit - singletopISR                              =  0.2026 +/- 0.9777
# INFO - cabinetry.fit - singletopInterference                     =  0.5221 +/- 0.9621
# INFO - cabinetry.fit - TtbarFSR                                  = -0.0198 +/- 0.7195
# INFO - cabinetry.fit - TtbarFragmentation                        =  0.3709 +/- 0.8978
# INFO - cabinetry.fit - TtbarHardscattering                       =  0.2727 +/- 0.6473
# INFO - cabinetry.fit - TtbarISR                                  = -0.1119 +/- 0.8241
# INFO - cabinetry.fit - ttvRenormFac                              = -0.0062 +/- 0.9856
# INFO - cabinetry.fit - wjetsCKKW                                 =  0.0060 +/- 1.0554
# INFO - cabinetry.fit - wjetsPDF                                  =  0.0186 +/- 0.9932
# INFO - cabinetry.fit - wjetsQSF                                  = -0.0047 +/- 1.0682
# INFO - cabinetry.fit - wjetsRenormFac                            = -0.0101 +/- 1.0036
# INFO - cabinetry.fit - multiboson                                =  0.0000 +/- 0.9933
# INFO - cabinetry.fit - zjetsCKKW                                 = -0.0010 +/- 0.9965
# INFO - cabinetry.fit - zjetsPDF                                  = -0.0002 +/- 0.9933
# INFO - cabinetry.fit - zjetsQSF                                  = -0.0002 +/- 0.9938
# INFO - cabinetry.fit - zjetsRenormFac                            =  0.0008 +/- 0.9965
# INFO - cabinetry.fit - lumi                                      =  1.0000 +/- 0.0000  (constant)
# INFO - cabinetry.fit - mu_SIG                                    =  1.0722 +/- 0.9081
# INFO - cabinetry.fit - mu_ST                                     =  1.0723 +/- 0.7093
# INFO - cabinetry.fit - mu_Top                                    =  0.9146 +/- 0.1252
# INFO - cabinetry.fit - mu_W                                      =  1.2268 +/- 0.2535
# INFO - cabinetry.fit - SigXSec                                   = -0.0004 +/- 0.9935
# INFO - cabinetry.fit - trigger                                   =  0.0060 +/- 0.9933
# INFO - cabinetry.fit - diboson_XS                                =  0.0012 +/- 0.9933
# INFO - cabinetry.fit - ttH_XS                                    =  0.0010 +/- 0.9933
# INFO - cabinetry.fit - ttv_XS                                    =  0.0156 +/- 0.9921
# INFO - cabinetry.fit - multiboson_XS                             = -0.0001 +/- 0.9934
# INFO - cabinetry.fit - zjets_XS                                  =  0.0005 +/- 0.9933
# INFO - cabinetry.fit - staterror_SRHMEM_mct2[0]                  =  0.9846 +/- 0.1427
# INFO - cabinetry.fit - staterror_SRHMEM_mct2[1]                  =  0.9968 +/- 0.1830
# INFO - cabinetry.fit - staterror_SRHMEM_mct2[2]                  =  1.0184 +/- 0.1735
# INFO - cabinetry.fit - staterror_SRLMEM_mct2[0]                  =  1.0319 +/- 0.0946
# INFO - cabinetry.fit - staterror_SRLMEM_mct2[1]                  =  1.0050 +/- 0.0992
# INFO - cabinetry.fit - staterror_SRLMEM_mct2[2]                  =  0.9950 +/- 0.0933
# INFO - cabinetry.fit - staterror_SRMMEM_mct2[0]                  =  0.9953 +/- 0.1636
# INFO - cabinetry.fit - staterror_SRMMEM_mct2[1]                  =  1.0589 +/- 0.1977
# INFO - cabinetry.fit - staterror_SRMMEM_mct2[2]                  =  0.9730 +/- 0.2030
# INFO - cabinetry.fit - staterror_STCREM_cuts[0]                  =  0.9981 +/- 0.0314
# INFO - cabinetry.fit - staterror_TRHMEM_cuts[0]                  =  0.9994 +/- 0.0164
# INFO - cabinetry.fit - staterror_TRLMEM_cuts[0]                  =  0.9980 +/- 0.0116
# INFO - cabinetry.fit - staterror_TRMMEM_cuts[0]                  =  1.0022 +/- 0.0124
# INFO - cabinetry.fit - staterror_WREM_cuts[0]                    =  1.0006 +/- 0.0361

# %% [markdown]
# <br>
# To parse the results more easily, let's visualize them.

# %%
cabinetry.visualize.pulls(ATLAS_fit_results)
# Out:
# INFO - cabinetry.visualize.utils - saving figure as figures/pulls.pdf

# %% [markdown]
# <br>
#
# # Bonus material
#
# Additional material that probably does not fit into the main talk. Check it out for more information!

# %% [markdown]
# <br>
#
# ### Command line interface
#
# `cabinetry` also provides a [command line interface](https://cabinetry.readthedocs.io/en/latest/cli.html). Feel free to explore it!

# %%
! cabinetry --help
# Out:
# Usage: cabinetry [OPTIONS] COMMAND [ARGS]...
#
#   Entrypoint to the cabinetry CLI.
#
# Options:
#   --version  Show the version and exit.
#   --help     Show this message and exit.
#
# Commands:
#   templates      Produces template histograms.
#   postprocess    Post-processes template histograms.
#   workspace      Produces a ``pyhf`` workspace.
#   fit            Fits a workspace and optionally visualizes the results.
#   ranking        Ranks nuisance parameters and visualizes the result.
#   scan           Performs and visualizes a likelihood scan over a parameter.
#   limit          Calculates upper limits and visualizes CLs distribution.
#   significance   Calculates observed and expected discovery significance.
#   data-mc        Visualizes distributions of fit model and observed data.
#   yields         Creates yield tables of fit model and observed data.
#   modifier-grid  Visualizes modifier structure of a model.

# %% [markdown]
# <br>
#
# ### Input histograms via a custom function
#
# It is possible to inject custom code into `cabinetry`, which is used for template histogram creation. You can find more details in the [documentation](https://cabinetry.readthedocs.io/en/latest/advanced.html#overrides-for-template-building).

# %%
my_router = cabinetry.route.Router()

# define a custom template builder function that is executed for data samples
@my_router.register_template_builder(sample_name="Data")
def build_data_hist(region: dict, sample: dict, systematic: dict, template: str):
    hist = bh.Histogram(
        bh.axis.Variable(region["Binning"], underflow=False, overflow=False),
        storage=bh.storage.Weight(),
    )
    yields = np.asarray([17, 12, 25, 20])
    variance = np.asarray([1.5, 1.2, 1.8, 1.6])
    hist[...] = np.stack([yields, variance], axis=-1)
    return hist  # return a boost-histogram histogram

custom_config = copy.deepcopy(config)
custom_config["General"]["HistogramFolder"] = "histograms_custom/"
cabinetry.templates.build(custom_config, router=my_router)
# Out:
# DEBUG - cabinetry.route -   in region Signal_region
# DEBUG - cabinetry.route -     reading sample Data
# DEBUG - cabinetry.route -       variation Nominal
# DEBUG - cabinetry.route - executing user-defined override build_data_hist
# DEBUG - cabinetry.histo - saving histogram to histograms_custom/Signal_region_Data.npz
# DEBUG - cabinetry.route -     reading sample Signal
# DEBUG - cabinetry.route -       variation Nominal
# DEBUG - cabinetry.contrib.histogram_creator - reading input ntuples ['input/prediction.root:signal']
# WARNING - cabinetry.histo - Signal_region_Signal has empty bins: [0]
# DEBUG - cabinetry.histo - saving histogram to histograms_custom/Signal_region_Signal.npz
# DEBUG - cabinetry.route -     reading sample Background
# DEBUG - cabinetry.route -       variation Nominal
# DEBUG - cabinetry.contrib.histogram_creator - reading input ntuples ['input/prediction.root:background']
# DEBUG - cabinetry.histo - saving histogram to histograms_custom/Signal_region_Background.npz
# DEBUG - cabinetry.route -       variation Modeling Up
# DEBUG - cabinetry.contrib.histogram_creator - reading input ntuples ['input/prediction.root:background_varied']
# DEBUG - cabinetry.histo - saving histogram to histograms_custom/Signal_region_Background_Modeling_Up.npz
# DEBUG - cabinetry.route -       variation WeightBasedModeling Up
# DEBUG - cabinetry.contrib.histogram_creator - reading input ntuples ['input/prediction.root:background']
# DEBUG - cabinetry.histo - saving histogram to histograms_custom/Signal_region_Background_WeightBasedModeling_Up.npz
# DEBUG - cabinetry.route -       variation WeightBasedModeling Down
# DEBUG - cabinetry.contrib.histogram_creator - reading input ntuples ['input/prediction.root:background']
# DEBUG - cabinetry.histo - saving histogram to histograms_custom/Signal_region_Background_WeightBasedModeling_Down.npz

# %% [markdown]
# The histogram creation called our function to create the data histogram.
#
# We can load the histogram and check the yields to verify they were correctly picked up.

# %%
h = cabinetry.histo.Histogram.from_path(pathlib.Path("histograms_custom/Signal_region_Data.npz"))
h.values()
# Out:
# array([17., 12., 25., 20.])

# %% [markdown]
# <br>
#
# ### Histogram smoothing
#
# This shows how to apply smoothing to a histogram after producing it. We copy our config and save the resulting histograms in a new location to not interfere with the model we have used so far.

# %%
smoothing_config = copy.deepcopy(config)
smoothing_config["General"]["HistogramFolder"] = "histograms_smoothing/"
smoothing_config.update({
   "Systematics":[
      {
         "Name":"Modeling",
         "Up": {"SamplePath": "prediction.root", "Tree": "background_varied"},
         "Down": {"Symmetrize": True},
         "Samples": "Background",
         "Smoothing": {"Algorithm": "353QH, twice"},  # smoothing applied
         "Type": "NormPlusShape"
      }
   ]
})
cabinetry.templates.build(smoothing_config, method="uproot")
cabinetry.templates.postprocess(smoothing_config)
_ = cabinetry.visualize.templates(smoothing_config)
# Out:
# DEBUG - cabinetry.route -   in region Signal_region
# DEBUG - cabinetry.route -     reading sample Data
# DEBUG - cabinetry.route -       variation Nominal
# DEBUG - cabinetry.contrib.histogram_creator - reading input ntuples ['input/data.root:pseudodata']
# DEBUG - cabinetry.histo - saving histogram to histograms_smoothing/Signal_region_Data.npz
# DEBUG - cabinetry.route -     reading sample Signal
# DEBUG - cabinetry.route -       variation Nominal
# DEBUG - cabinetry.contrib.histogram_creator - reading input ntuples ['input/prediction.root:signal']
# WARNING - cabinetry.histo - Signal_region_Signal has empty bins: [0]
# DEBUG - cabinetry.histo - saving histogram to histograms_smoothing/Signal_region_Signal.npz
# DEBUG - cabinetry.route -     reading sample Background
# DEBUG - cabinetry.route -       variation Nominal
# DEBUG - cabinetry.contrib.histogram_creator - reading input ntuples ['input/prediction.root:background']
# DEBUG - cabinetry.histo - saving histogram to histograms_smoothing/Signal_region_Background.npz
# DEBUG - cabinetry.route -       variation Modeling Up
# DEBUG - cabinetry.contrib.histogram_creator - reading input ntuples ['input/prediction.root:background_varied']
# DEBUG - cabinetry.histo - saving histogram to histograms_smoothing/Signal_region_Background_Modeling_Up.npz
# DEBUG - cabinetry.route -   in region Signal_region
# DEBUG - cabinetry.route -     reading sample Data
# DEBUG - cabinetry.route -       variation Nominal
# DEBUG - cabinetry.histo - saving histogram to histograms_smoothing/Signal_region_Data_modified.npz
# DEBUG - cabinetry.route -     reading sample Signal
# DEBUG - cabinetry.route -       variation Nominal
# WARNING - cabinetry.histo - Signal_region_Signal has empty bins: [0]
# DEBUG - cabinetry.histo - saving histogram to histograms_smoothing/Signal_region_Signal_modified.npz
# DEBUG - cabinetry.route -     reading sample Background
# DEBUG - cabinetry.route -       variation Nominal
# DEBUG - cabinetry.histo - saving histogram to histograms_smoothing/Signal_region_Background_modified.npz
# DEBUG - cabinetry.route -       variation Modeling Up
# DEBUG - cabinetry.templates.postprocessor - applying smoothing to Signal_region_Background_Modeling_Up
# DEBUG - cabinetry.histo - saving histogram to histograms_smoothing/Signal_region_Background_Modeling_Up_modified.npz
# INFO - cabinetry.visualize - visualizing systematic templates
# INFO - cabinetry.visualize.utils - saving figure as figures/templates/Signal_region_Background_Modeling.pdf

# %% [markdown]
# The original histogram is shown with the dotted line, and the dashed line shows the histogram after applying the [353QH, twice](https://cds.cern.ch/record/186223/) algorithm (same as `TH1::SmoothArray` in `ROOT`).

# %% [markdown]
# <br>
#
# ### Exploring histograms with `hist`
#
# `cabinetry` uses `boost-histogram` internally to handle histograms. That means we can use `hist` for visualization. There are multiple ways for loading histograms, the method below uses information from the config.

# %%
cabinetry_histogram = cabinetry.histo.Histogram.from_config(
    config["General"]["HistogramFolder"],
    config["Regions"][0],  # we only have one region: Signal_region
    config["Samples"][0],  # data
    {"Name": "Nominal"},   # no systematics
)
_ = hist.Hist(cabinetry_histogram).plot()
# Out:
# INFO - cabinetry.histo - no modified histogram histograms/Signal_region_Data_modified.npz found, loading un-modified histogram

# %% [markdown]
# <br>
#
# ### Going back and forth between `cabinetry` and `pyhf`
#
# You can go back and forth between `cabinetry` and `pyhf`. Here is a simple example that builds the Asimov dataset with `cabinetry` and performs a fit with `pyhf`.

# %%
asimov_data = cabinetry.model_utils.asimov_data(model)
pyhf.infer.mle.fit(asimov_data, model)
# Out:
# array([0., 0., 1., 0., 1., 1., 1., 1.])

# %% [markdown]
# <br>
#
# You can also take advantage of the `pyhf` workspace format and edit parameters directly and then build a new model. Let's fix the `Modeling` nuisance parameter to `-0.5` and repeat the fit, this time with `cabinetry`. The model is obtained directly via `pyhf` here instead of using `cabinetry.model_utils.model_and_data`.

# %%
spec_edited = copy.deepcopy(spec)
spec_edited["measurements"][0]["config"]["parameters"].append({"name": "Modeling", "inits": [-0.5], "fixed": True})
model_edited = pyhf.Workspace(spec_edited).model()
_ = cabinetry.fit.fit(model_edited, data)
# Out:
# INFO - pyhf.workspace - Validating spec against schema: workspace.json
# INFO - pyhf.pdf - Validating spec against schema: model.json
# INFO - pyhf.pdf - adding modifier Modeling (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier WeightBasedModeling (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier Signal_norm (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier Luminosity (1 new nuisance parameters)
# INFO - pyhf.pdf - adding modifier staterror_Signal_region (4 new nuisance parameters)
# INFO - cabinetry.fit - performing maximum likelihood fit
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 17.29                      │              Nfcn = 209              │
# │ EDM = 0.000122 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 17.292621 at best-fit point
# INFO - cabinetry.fit - fit results (with symmetric uncertainties):
# INFO - cabinetry.fit - Modeling                   = -0.5000 +/- 0.0000  (constant)
# INFO - cabinetry.fit - WeightBasedModeling        = -0.7705 +/- 0.2218
# INFO - cabinetry.fit - Signal_norm                =  1.9623 +/- 0.3452
# INFO - cabinetry.fit - Luminosity                 = -0.1040 +/- 0.9894
# INFO - cabinetry.fit - staterror_Signal_region[0] =  0.9987 +/- 0.0405
# INFO - cabinetry.fit - staterror_Signal_region[1] =  0.9905 +/- 0.0377
# INFO - cabinetry.fit - staterror_Signal_region[2] =  1.0189 +/- 0.0365
# INFO - cabinetry.fit - staterror_Signal_region[3] =  0.9836 +/- 0.0425

# %% [markdown]
# The `Modeling` parameter shows up at its fixed value `-0.5` in the fit results, with an uncertainty of `0` since it is set to constant.

# %% [markdown]
# <br>
#
# ### Further MLE options: MINOS and goodness-of-fit
#
# The `cabinetry.fit.fit` API allows use of the [MINOS algorithm](https://iminuit.readthedocs.io/en/stable/reference.html#iminuit.Minuit.minos) to compute confidence intervals via parameter scans. All parameters for which the algorithm should be run have to be listed.

# %%
_ = cabinetry.fit.fit(model, data, minos=["Signal_norm", "Modeling"])
# Out:
# INFO - cabinetry.fit - performing maximum likelihood fit
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 17.19                      │              Nfcn = 310              │
# │ EDM = 2.82e-05 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# INFO - cabinetry.fit - running MINOS for Signal_norm
# INFO - cabinetry.fit - running MINOS for Modeling
# INFO - cabinetry.fit - MINOS results:
# INFO - cabinetry.fit - Modeling                   = -0.3258 -0.5440 +0.4348
# INFO - cabinetry.fit - Signal_norm                =  1.6927 -0.9612 +0.9021
# DEBUG - cabinetry.fit - -2 log(L) = 17.194232 at best-fit point
# INFO - cabinetry.fit - fit results (with symmetric uncertainties):
# INFO - cabinetry.fit - Modeling                   = -0.3258 +/- 0.5551
# INFO - cabinetry.fit - WeightBasedModeling        = -0.5868 +/- 0.6266
# INFO - cabinetry.fit - Signal_norm                =  1.6927 +/- 0.9455
# INFO - cabinetry.fit - Luminosity                 = -0.0899 +/- 0.9915
# INFO - cabinetry.fit - staterror_Signal_region[0] =  1.0009 +/- 0.0411
# INFO - cabinetry.fit - staterror_Signal_region[1] =  0.9891 +/- 0.0379
# INFO - cabinetry.fit - staterror_Signal_region[2] =  1.0197 +/- 0.0365
# INFO - cabinetry.fit - staterror_Signal_region[3] =  0.9829 +/- 0.0425

# %% [markdown]
# MINOS uncertainties are not restricted to be symmetric by construction.
#
# `cabinetry` also implementes a goodness-of-fit calculation using the [saturated model](http://www.physics.ucla.edu/~cousins/stats/cousins_saturated.pdf).

# %%
_ = cabinetry.fit.fit(model, data, goodness_of_fit=True)
# Out:
# INFO - cabinetry.fit - performing maximum likelihood fit
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 17.19                      │              Nfcn = 310              │
# │ EDM = 2.82e-05 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 17.194232 at best-fit point
# INFO - cabinetry.fit - fit results (with symmetric uncertainties):
# INFO - cabinetry.fit - Modeling                   = -0.3258 +/- 0.5551
# INFO - cabinetry.fit - WeightBasedModeling        = -0.5868 +/- 0.6266
# INFO - cabinetry.fit - Signal_norm                =  1.6927 +/- 0.9455
# INFO - cabinetry.fit - Luminosity                 = -0.0899 +/- 0.9915
# INFO - cabinetry.fit - staterror_Signal_region[0] =  1.0009 +/- 0.0411
# INFO - cabinetry.fit - staterror_Signal_region[1] =  0.9891 +/- 0.0379
# INFO - cabinetry.fit - staterror_Signal_region[2] =  1.0197 +/- 0.0365
# INFO - cabinetry.fit - staterror_Signal_region[3] =  0.9829 +/- 0.0425
# INFO - cabinetry.fit - calculating goodness-of-fit
# DEBUG - cabinetry.fit - Delta NLL = 2.069744
# DEBUG - cabinetry.fit - number of degrees of freedom: 3
# INFO - cabinetry.fit - p-value for goodness-of-fit test: 24.68%

# %% [markdown]
# <br>
#
# ### Likelihood scan
#
# We can perform a likelihood scan, where we hold a parameter fixed at different values and perform a MLE for the other parameters, recording the likelihood at each step in the scan.

# %%
scan_results = cabinetry.fit.scan(model, data, "Signal_norm", n_steps=5)
# Out:
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 17.19                      │              Nfcn = 310              │
# │ EDM = 2.82e-05 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 17.194232 at best-fit point
# INFO - cabinetry.fit - performing likelihood scan for Signal_norm in range (-0.198, 3.584) with 5 steps
# DEBUG - cabinetry.fit - performing fit with Signal_norm = -0.198
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 21.31                      │              Nfcn = 219              │
# │ EDM = 2.63e-05 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 21.305066 at best-fit point
# DEBUG - cabinetry.fit - performing fit with Signal_norm = 0.747
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 18.16                      │              Nfcn = 201              │
# │ EDM = 1.48e-06 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 18.161268 at best-fit point
# DEBUG - cabinetry.fit - performing fit with Signal_norm = 1.693
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 17.19                      │              Nfcn = 217              │
# │ EDM = 4.46e-06 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 17.194220 at best-fit point
# DEBUG - cabinetry.fit - performing fit with Signal_norm = 2.638
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 18.3                       │              Nfcn = 217              │
# │ EDM = 0.000107 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 18.298797 at best-fit point
# DEBUG - cabinetry.fit - performing fit with Signal_norm = 3.584
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 22.09                      │              Nfcn = 239              │
# │ EDM = 4.29e-06 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 22.092774 at best-fit point

# %% [markdown]
# <br>
# The scan in this example shows relatively good agreement with a naive Gaussian approximation.

# %%
cabinetry.visualize.scan(scan_results)
# Out:
# INFO - cabinetry.visualize.utils - saving figure as figures/scan_Signal_norm.pdf

# %% [markdown]
# <br>
#
# ### Nuisance parameter ranking
#
# We can rank nuisance parameters (NPs) by their impact on the POI: how much does the POI change if the NP varies within its uncertainty? This requires a lot of MLE fits.

# %%
ranking_results = cabinetry.fit.ranking(model, data, fit_results=fit_results)
# Out:
# INFO - cabinetry.fit - calculating impact of Modeling on Signal_norm
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 35.27                      │              Nfcn = 200              │
# │ EDM = 4.39e-05 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 35.272232 at best-fit point
# DEBUG - cabinetry.fit - POI is 0.012156, difference to nominal is -1.680549
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 20.48                      │              Nfcn = 267              │
# │ EDM = 1.86e-05 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 20.476271 at best-fit point
# DEBUG - cabinetry.fit - POI is 3.106776, difference to nominal is 1.414072
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 19.46                      │              Nfcn = 200              │
# │ EDM = 2.23e-05 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 19.458518 at best-fit point
# DEBUG - cabinetry.fit - POI is 0.591151, difference to nominal is -1.101553
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 18.24                      │              Nfcn = 247              │
# │ EDM = 4.26e-05 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 18.235701 at best-fit point
# DEBUG - cabinetry.fit - POI is 2.535446, difference to nominal is 0.842741
# INFO - cabinetry.fit - calculating impact of WeightBasedModeling on Signal_norm
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 20.43                      │              Nfcn = 201              │
# │ EDM = 5.17e-05 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 20.430953 at best-fit point
# DEBUG - cabinetry.fit - POI is 0.175033, difference to nominal is -1.517672
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 19.62                      │              Nfcn = 225              │
# │ EDM = 8.02e-05 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 19.622371 at best-fit point
# DEBUG - cabinetry.fit - POI is 2.838532, difference to nominal is 1.145827
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 18.26                      │              Nfcn = 200              │
# │ EDM = 1.89e-06 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 18.264834 at best-fit point
# DEBUG - cabinetry.fit - POI is 0.795479, difference to nominal is -0.897226
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 18.16                      │              Nfcn = 221              │
# │ EDM = 8.4e-06 (Goal: 0.0002)     │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 18.158272 at best-fit point
# DEBUG - cabinetry.fit - POI is 2.455003, difference to nominal is 0.762298
# INFO - cabinetry.fit - calculating impact of Luminosity on Signal_norm
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 18.2                       │              Nfcn = 251              │
# │ EDM = 4.64e-06 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 18.195201 at best-fit point
# DEBUG - cabinetry.fit - POI is 1.540836, difference to nominal is -0.151869
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 18.21                      │              Nfcn = 251              │
# │ EDM = 5.3e-06 (Goal: 0.0002)     │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 18.208701 at best-fit point
# DEBUG - cabinetry.fit - POI is 1.859837, difference to nominal is 0.167132
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 18.18                      │              Nfcn = 251              │
# │ EDM = 4.84e-06 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 18.178098 at best-fit point
# DEBUG - cabinetry.fit - POI is 1.542018, difference to nominal is -0.150687
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 18.19                      │              Nfcn = 251              │
# │ EDM = 3.17e-06 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 18.191456 at best-fit point
# DEBUG - cabinetry.fit - POI is 1.859677, difference to nominal is 0.166973
# INFO - cabinetry.fit - calculating impact of staterror_Signal_region[0] on Signal_norm
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 18.24                      │              Nfcn = 269              │
# │ EDM = 9.77e-06 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 18.243446 at best-fit point
# DEBUG - cabinetry.fit - POI is 1.581691, difference to nominal is -0.111013
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 18.26                      │              Nfcn = 253              │
# │ EDM = 7.62e-06 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 18.258821 at best-fit point
# DEBUG - cabinetry.fit - POI is 1.800030, difference to nominal is 0.107325
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 18.19                      │              Nfcn = 253              │
# │ EDM = 5.93e-05 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 18.187039 at best-fit point
# DEBUG - cabinetry.fit - POI is 1.582589, difference to nominal is -0.110116
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 18.2                       │              Nfcn = 253              │
# │ EDM = 5.77e-06 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 18.201606 at best-fit point
# DEBUG - cabinetry.fit - POI is 1.796653, difference to nominal is 0.103949
# INFO - cabinetry.fit - calculating impact of staterror_Signal_region[1] on Signal_norm
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 18.26                      │              Nfcn = 270              │
# │ EDM = 4.77e-05 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 18.262489 at best-fit point
# DEBUG - cabinetry.fit - POI is 1.832269, difference to nominal is 0.139565
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 18.27                      │              Nfcn = 269              │
# │ EDM = 5.43e-05 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 18.267041 at best-fit point
# DEBUG - cabinetry.fit - POI is 1.538619, difference to nominal is -0.154086
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 18.19                      │              Nfcn = 270              │
# │ EDM = 4.98e-05 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 18.191800 at best-fit point
# DEBUG - cabinetry.fit - POI is 1.827494, difference to nominal is 0.134789
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 18.2                       │              Nfcn = 269              │
# │ EDM = 4.98e-05 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 18.195791 at best-fit point
# DEBUG - cabinetry.fit - POI is 1.544226, difference to nominal is -0.148479
# INFO - cabinetry.fit - calculating impact of staterror_Signal_region[2] on Signal_norm
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 18.29                      │              Nfcn = 252              │
# │ EDM = 0.000159 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 18.288581 at best-fit point
# DEBUG - cabinetry.fit - POI is 1.570446, difference to nominal is -0.122258
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 18.3                       │              Nfcn = 273              │
# │ EDM = 2.26e-09 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 18.303057 at best-fit point
# DEBUG - cabinetry.fit - POI is 1.805745, difference to nominal is 0.113041
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 18.19                      │              Nfcn = 255              │
# │ EDM = 7.64e-05 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 18.187687 at best-fit point
# DEBUG - cabinetry.fit - POI is 1.577197, difference to nominal is -0.115508
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 18.2                       │              Nfcn = 273              │
# │ EDM = 2.29e-09 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 18.200962 at best-fit point
# DEBUG - cabinetry.fit - POI is 1.800195, difference to nominal is 0.107491
# INFO - cabinetry.fit - calculating impact of staterror_Signal_region[3] on Signal_norm
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 18.22                      │              Nfcn = 271              │
# │ EDM = 1.59e-06 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 18.219323 at best-fit point
# DEBUG - cabinetry.fit - POI is 1.634909, difference to nominal is -0.057795
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 18.23                      │              Nfcn = 272              │
# │ EDM = 7.83e-05 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 18.227574 at best-fit point
# DEBUG - cabinetry.fit - POI is 1.747090, difference to nominal is 0.054386
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 18.19                      │              Nfcn = 271              │
# │ EDM = 1.68e-06 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 18.190309 at best-fit point
# DEBUG - cabinetry.fit - POI is 1.635694, difference to nominal is -0.057010
# INFO - cabinetry.fit - Migrad status:
# ┌─────────────────────────────────────────────────────────────────────────┐
# │                                Migrad                                   │
# ├──────────────────────────────────┬──────────────────────────────────────┤
# │ FCN = 18.2                       │              Nfcn = 272              │
# │ EDM = 7.77e-05 (Goal: 0.0002)    │                                      │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │          Valid Minimum           │   Below EDM threshold (goal x 10)    │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │      No parameters at limit      │           Below call limit           │
# ├──────────────────────────────────┼──────────────────────────────────────┤
# │             Hesse ok             │         Covariance accurate          │
# └──────────────────────────────────┴──────────────────────────────────────┘
# DEBUG - cabinetry.fit - -2 log(L) = 18.198326 at best-fit point
# DEBUG - cabinetry.fit - POI is 1.746291, difference to nominal is 0.053587

# %% [markdown]
# <br>
# The figure visualizes the impact of nuisance parameters on the POI in order of decreasing impact.

# %%
cabinetry.visualize.ranking(ranking_results)
# Out:
# INFO - cabinetry.visualize.utils - saving figure as figures/ranking.pdf
